# %% [markdown]
# <a href="https://colab.research.google.com/github/iamnmn9/FakeArtwork_UB_FolkArt/blob/main/FolkArt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
from PIL import Image
# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)


model.conf = 0.04 # Lower threshold for more detections

# Images
image = Image.open("/content/drive/MyDrive/ProjectData/s1/img/s10.jpg")
imgs = image.convert("L")
# Inference
results = model(imgs)

# Show results on image with bounding boxes
results.show()
results.print()
results.save()

results.xyxy[0]
results.pandas().xyxy[0]
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-6-15 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=1200x708 at 0x7F9B35FFF820>
# image 1/1: 708x1200 3 persons, 1 vase
# Speed: 5.2ms pre-process, 238.8ms inference, 1.2ms NMS per image at shape (1, 3, 384, 640)
# Saved 1 image to runs/detect/exp27
#          xmin       ymin         xmax        ymax  confidence  class    name
# 0  297.905090  67.897614   531.802002  630.044800    0.787915      0  person
# 1   32.594044  31.393194   292.140930  696.006714    0.637621      0  person
# 2  511.053284  50.079365   764.194153  674.654602    0.220429      0  person
# 3  950.395813  73.966530  1180.706665  685.219910    0.093684     75    vase

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
with open('/content/drive/MyDrive/ProjectData/s1/txt/p1.txt', "r") as file:

    text = file.read()

print(text)

doc = nlp(text)

for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Hail Durga, Ma Tara, destroyer of sorrows.
# Invincible as the strong southern winds, she is Nagendranandini (daughter of the king of mountains).
# As Ma Chandi, her ten arms stretch in ten directions.
# Her third eye shines brightly in the middle of her forehead.
# Lakshmi, with Saraswati on her left, Kartik and Ganesh
# Along with the lion, the Asura, Joya and Bijoya accompany the Mother.
#
# Hail Durga PERSON
# Ma Tara PERSON
# Nagendranandini PERSON
# Ma Chandi PERSON
# ten CARDINAL
# ten CARDINAL
# third ORDINAL
# Lakshmi GPE
# Saraswati ORG
# Kartik ORG
# Asura PERSON
# Bijoya LOC
